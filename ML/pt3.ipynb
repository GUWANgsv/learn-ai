# %% [markdown]
# ## polynomial regression
#
# not always when we draw best fit line become a straight line, sometimes it can be a curve. In that case we can use polynomial regression to fit the curve.

# %% [markdown]
# to make strait line to bend we do feature expansion
# example
# x=2
#
# ---
#
# after feature expansion
#
# x=2
#
# x**2=4
#
# x**3=8
#
# we create features using existing features.using this methode we can make strait line to bend and fit the curve.
#
# ![alt text](<Screenshot 2026-04-21 124309.png>)

# %% [markdown]
# ![alt text](<Screenshot 2026-04-21 140343.png>)

# %% [markdown]
# ![alt text](<Screenshot 2026-04-21 141922.png>)

# %% [markdown]
# A-this statement has to be always true r2 train < r2 test (r2 train > r2 test mean become overfitting )
# B-r2 has to be as close to 1 as possible
# what we do is
# first do the data clean basic stuff
# second we split the data into train and test
# third check for 1 degree/normal linear regression and check the A and B
# for forth it is not working properly so we do the
# the feature expansion ,check for 2 degree polynomial regression and check the A and B ,then still not good so go on make degree up by one until we get the best A and B
#
# still not working then we have to add regularization to avoid overfitting and check for the best r2 score.

# %% [markdown]
# for recal
#
# w1,w2→ weights
#
# y= w1*x1 + w2*x2 + b

# %% [markdown]
# Normal linear regression tries to minimize error but not enough to prevent overfitting. Regularization modifies this by adding a penalty for large weights
#
# MSE+penalty

# %% [markdown]
# 3 ways to add penalty
#
# ![alt text](<Screenshot 2026-04-21 192306.png>)
#
# shrinking
# use this when independent variables are highly correlated(eg:- same feature with 2 different units)
#
# ![alt text](<Screenshot 2026-04-21 192811.png>)
#
# selection
# use this when there are many irrelevant features
#
# ![alt text](<Screenshot 2026-04-21 195708.png>)
#
# ![alt text](<Screenshot 2026-04-21 195844.png>)
#
# ![alt text](<Screenshot 2026-04-21 200022.png>)
#
# ![alt text](<Screenshot 2026-04-21 200437.png>)
#
# we get the alpha when exact point that testr2>trainr2
#
# ![alt text](<Screenshot 2026-04-21 200605.png>)

# %% [markdown]
# other

# %% [markdown]
# about correlation

# %% [markdown]
# ![alt text](<Screenshot 2026-04-21 234545.png>)

# %% [markdown]
# ![alt text](<Screenshot 2026-04-21 234723.png>)

# %% [markdown]
# when there are correlation get confused sometimes
#
# partial correlation
#
# ![alt text](<Screenshot 2026-04-22 000112.png>)
#
# there no direct correlation between ice cream and drowning but there is a correlation between them because of the temperature.
#
#
# multicollinearity
#
# ![alt text](<Screenshot 2026-04-22 000248.png>)
#
# when there are 2 or more independent variables are highly correlated with each other then it is called multicollinearity. (eg:-same feature with 2 different units when this happens some time we have to remove i feature to avoid multicollinearity)

# %% [markdown]
# ![alt text](<Screenshot 2026-04-22 000617.png>)
