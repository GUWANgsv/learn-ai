# %% [markdown]
# ## Logistic Regression & binary classification
#
# ![alt text](<Screenshot 2026-04-22 105041.png>)

# %% [markdown]
# When there are outliers in the dataset, a normal linear regression model can fail because the best-fit line gets skewed (for example, pulled downward). This happens because linear regression is sensitive to extreme values.
#
# solution for this
#
# ![alt text](<Screenshot 2026-04-22 113007.png>)
#
# but we use
#
# ![alt text](<Screenshot 2026-04-22 113247.png>)
#
# but thre are some problems with this approach
#
# ![alt text](<Screenshot 2026-04-22 113528.png>)to
#
# to avoid this problem we uselog loss function
#
# ![alt text](<Screenshot 2026-04-22 114949.png>)
#
#
# ![alt text](<Screenshot 2026-04-22 115154.png>)
#
# why we use confusion matrix?
# model accuracy can be misleading if you have imbalanced classes.
#
# ![alt text](<Screenshot 2026-04-22 115944.png>)
#
# confusion matrix
#
# ![alt text](<Screenshot 2026-04-22 115342.png>)
#
#
# ![alt text](<Screenshot 2026-04-22 120157.png>)
# eg:-
#
# ![alt text](<Screenshot 2026-04-22 120746.png>)
#
# to balance precision and recall
#
# ![alt text](<Screenshot 2026-04-22 121146.png>)

# %% [markdown]
# the route of binary classification
#
# ![alt text](<Screenshot 2026-04-22 121300.png>)
